# %% [markdown]
# # The Battle of the Neighborhood (week2)
#
# ##### By MFugulin Jul 2021
#
#
#
#
# ### Introduction
#
# Due to the "Lockdown", several restaurants closed their doors, with the need to adapt their ways of serving their customers.
#
# Two forms of service were established by most restaurants and snack bars: delivery and on-site collection (collection on the sidewalk), as they present the lowest initial investment.
#
# In "Collect on the Sidewalk" mode, the customer continues to go to the place, but withdrawing their orders, where the cost is almost zero for the entrepreneur. The other modality that already existed before was delivery through companies such as Ritual, Doordash, Skip the Dishes, among others, but the cost is high.
#
# Thus, some entrepreneurs thought of themselves starting the process of delivering products to their customers, within a restricted distance area.
#
# This is an excellent opportunity to create a model that can be suitable for any restaurant that wants this analysis, helping small business owners to adapt their businesses, get to know the competition better and make a better investment decision in this service (or not).
#
#
# ### Business Problem
# Know better your Neighborhood and competition for delivery services: How many restaurants are there in the area to offer the analysis? What types of restaurants are in this region? What is the income of people in the same region to determine the prices to be charged? Where is the best area to provide the delivery services wit best return of investment? The budget is limite and all investments must be very well oriented.
#
#
# ### Objective
# Create an Analytical Model to obtain all data and raise all the information necessary to help the small business owner to keep suing business during the lockdown and after.
#
#  For that, we will create a first model using Toronto as a reference and seek for the restaurants that are 5km away from Toronto to be used as a benchmark.
#
# One key outcome of this model is determining the most strategic region(s) in Toronto for restaurant(s) can strategically expand its services, as the budget is limited due to the limitations imposed during the pandemic.
#
# The model will be able to serve several restaurant owners who need to provide delivery services. This business analysis model can be applied to any restaurant, we just will need to include the locations to provide this analytical report to the customer and help him to understand the scenario and data relevant for the investments.
#
#
# ### The process to reach the goals
# Join libraries and databases data into a data frame.
# For the number of restaurants, types, etc., I used the Foursquare into 5 Km distance of a specific point (this point can be changed as need per the restaurant interested in this analysis).
#
# All strategic data as locations, neighbourhoods, incomes (net) will be analyzed via k-means clustering.
#
# ##### Sources/Databases
# - Foursquare to find restaurants
# - Wellbeing Toronto for Demographic/ socioeconomic
# - Wikipedia to find the locations

# %% [markdown]
# ## Importing Datasets

# %% [markdown]
# ### Toronto Data

# %%
# libraries
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup

# Wikipedia
df = pd.read_html('https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=945633050')[0]
df = df[df.Borough!='Not assigned']
df.shape
# Out:
# (210, 3)

# %%
#copy df
toronto_df = df.copy()

# Nneighborhood coordinates & Data Shape
location_coordinates = pd.read_csv (r'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv')
location_coordinates.rename(columns={'Postal Code': 'Postcode'}, inplace=True)

# Data shape
toronto_loc_data = pd.merge(toronto_df, location_coordinates, on='Postcode', how='inner')
toronto_loc_data
# Out:
#     Postcode           Borough             Neighbourhood   Latitude  Longitude
# 0        M3A        North York                 Parkwoods  43.753259 -79.329656
# 1        M4A        North York          Victoria Village  43.725882 -79.315572
# 2        M5A  Downtown Toronto              Harbourfront  43.654260 -79.360636
# 3        M6A        North York          Lawrence Heights  43.718518 -79.464763
# 4        M6A        North York            Lawrence Manor  43.718518 -79.464763
# ..       ...               ...                       ...        ...        ...
# 205      M8Z         Etobicoke  Kingsway Park South West  43.628841 -79.520999
# 206      M8Z         Etobicoke                 Mimico NW  43.628841 -79.520999
# 207      M8Z         Etobicoke        The Queensway West  43.628841 -79.520999
# 208      M8Z         Etobicoke     Royal York South West  43.628841 -79.520999
# 209      M8Z         Etobicoke            South of Bloor  43.628841 -79.520999
#
# [210 rows x 5 columns]

# %% [markdown]
# ### Household Income Dataset - Toronto

# %%
# Household income 
income_toronto_url = 'https://raw.githubusercontent.com/thatjosh/IBM-Data-Science-Capstone-Project/master/income_toronto.csv'
income_path = pd.read_csv(income_toronto_url)
df_income = pd.DataFrame(income_path)
df_income.drop(['Neighbourhood Id'], axis=1, inplace=True)
df_income.shape
# Out:
# (140, 2)

# %% [markdown]
# ### Population Size Dataset

# %%
pop_toronto_url = 'https://raw.githubusercontent.com/thatjosh/IBM-Data-Science-Capstone-Project/master/population_toronto.csv'
pop_path = pd.read_csv(pop_toronto_url)
df_pop = pd.DataFrame(pop_path)
df_pop.drop(['Neighbourhood Id'], axis=1, inplace=True)
df_pop.shape
# Out:
# (140, 2)

# %%
print ('\n Neighbourhood and Total Population')
df_pop
# Out:
#  Neighbourhood and Total Population
#                          Neighbourhood  Total Population
# 0               West Humber-Clairville           33312.0
# 1    Mount Olive-Silverstone-Jamestown           32954.0
# 2         Thistletown-Beaumond Heights           10360.0
# 3                      Rexdale-Kipling           10529.0
# 4                     Elms-Old Rexdale            9456.0
# ..                                 ...               ...
# 135                          West Hill           27392.0
# 136                             Woburn           53485.0
# 137                      Eglinton East           22776.0
# 138                Scarborough Village           16724.0
# 139                          Guildwood            9917.0
#
# [140 rows x 2 columns]

# %% [markdown]
# ### Join Datasets

# %%
loc_stats = pd.merge(df_income, df_pop, on='Neighbourhood', how='inner')
final_loc_stats = pd.merge(loc_stats, toronto_loc_data, on='Neighbourhood', how='inner')
final_loc_stats.head(35)
# Out:
#           Neighbourhood  After-Tax Household Income  Total Population  \
# 0         Markland Wood                     64297.0           10554.0
# 1           New Toronto                     40859.0           11463.0
# 2           Long Branch                     47680.0           10084.0
# 3             Alderwood                     61402.0           12054.0
# 4         Humber Summit                     53272.0           12416.0
# 5        Bathurst Manor                     51076.0           15873.0
# 6       Willowdale West                     54226.0           16936.0
# 7      Victoria Village                     43743.0           17510.0
# 8       Flemingdon Park                     43511.0           21933.0
# 9     Hillcrest Village                     57682.0           16934.0
# 10      Bayview Village                     58028.0           21396.0
# 11           Henry Farm                     47659.0           15723.0
# 12     Thorncliffe Park                     38645.0           21108.0
# 13          The Beaches                     70957.0           21567.0
# 14      Little Portugal                     52519.0           15559.0
# 15         Roncesvalles                     46883.0           14974.0
# 16    Forest Hill North                     53978.0           12806.0
# 17   Humewood-Cedarvale                     49252.0           14365.0
# 18               Weston                     41356.0           17992.0
# 19         Mount Dennis                     43790.0           13593.0
# 20             Oakridge                     32079.0           13845.0
# 21           Cliffcrest                     60384.0           15935.0
# 22         Kennedy Park                     41776.0           17123.0
# 23              Ionview                     42971.0           13641.0
# 24          Dorset Park                     47630.0           25003.0
# 25      Agincourt North                     55893.0           29113.0
# 26             Milliken                     55464.0           26572.0
# 27                Rouge                     72784.0           46496.0
# 28              Malvern                     53425.0           43794.0
# 29       Highland Creek                     87321.0           12494.0
# 30          Morningside                     50069.0           17455.0
# 31            West Hill                     46803.0           27392.0
# 32               Woburn                     47908.0           53485.0
# 33  Scarborough Village                     40181.0           16724.0
# 34            Guildwood                     67678.0            9917.0
#
#    Postcode          Borough   Latitude  Longitude
# 0       M9C        Etobicoke  43.643515 -79.577201
# 1       M8V        Etobicoke  43.605647 -79.501321
# 2       M8W        Etobicoke  43.602414 -79.543484
# 3       M8W        Etobicoke  43.602414 -79.543484
# 4       M9L       North York  43.756303 -79.565963
# 5       M3H       North York  43.754328 -79.442259
# 6       M2R       North York  43.782736 -79.442259
# 7       M4A       North York  43.725882 -79.315572
# 8       M3C       North York  43.725900 -79.340923
# 9       M2H       North York  43.803762 -79.363452
# 10      M2K       North York  43.786947 -79.385975
# 11      M2J       North York  43.778517 -79.346556
# 12      M4H        East York  43.705369 -79.349372
# 13      M4E     East Toronto  43.676357 -79.293031
# 14      M6J     West Toronto  43.647927 -79.419750
# 15      M6R     West Toronto  43.648960 -79.456325
# 16      M5P  Central Toronto  43.696948 -79.411307
# 17      M6C             York  43.693781 -79.428191
# 18      M9N             York  43.706876 -79.518188
# 19      M6M             York  43.691116 -79.476013
# 20      M1L      Scarborough  43.711112 -79.284577
# 21      M1M      Scarborough  43.716316 -79.239476
# 22      M1K      Scarborough  43.727929 -79.262029
# 23      M1K      Scarborough  43.727929 -79.262029
# 24      M1P      Scarborough  43.757410 -79.273304
# 25      M1V      Scarborough  43.815252 -79.284577
# 26      M1V      Scarborough  43.815252 -79.284577
# 27      M1B      Scarborough  43.806686 -79.194353
# 28      M1B      Scarborough  43.806686 -79.194353
# 29      M1C      Scarborough  43.784535 -79.160497
# 30      M1E      Scarborough  43.763573 -79.188711
# 31      M1E      Scarborough  43.763573 -79.188711
# 32      M1G      Scarborough  43.770992 -79.216917
# 33      M1J      Scarborough  43.744734 -79.239476
# 34      M1E      Scarborough  43.763573 -79.188711

# %% [markdown]
# ### Foursquare

# %%
# My Credentials
CLIENT_ID = '4BED2AZYUDCEWQPPQQZZ5RBDQXDMQFBCWMHWNORZA3B0WSRC' # your Foursquare ID
CLIENT_SECRET = 'SHNJOCVCLRZO2EOKPR53ASTBYF0PQH1ZRDR05B52PGICWF04' # your Foursquare Secret
ACCESS_TOKEN = 'DWHEBCWF3JGXKY0Z5YQJBABAFILEDGU0FL5K1UII45LYFX1H'
VERSION = '20180604' # Foursquare API version
LIMIT = 300 # A default Foursquare API limit value
categoryId = 'zz'

# libraries
from pandas.io.json import json_normalize

# %%
# Forsquare location
radius = 5000
search_query = 'Restaurant*'

latitude = 43.643515
longitude = -79.577201

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT, categoryId)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4BED2AZYUDCEWQPPQQZZ5RBDQXDMQFBCWMHWNORZA3B0WSRC&client_secret=SHNJOCVCLRZO2EOKPR53ASTBYF0PQH1ZRDR05B52PGICWF04&ll=43.643515,-79.577201&oauth_token=DWHEBCWF3JGXKY0Z5YQJBABAFILEDGU0FL5K1UII45LYFX1H&v=20180604&query=Restaurant*&radius=5000&limit=300'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60f4954885ade9406e645013'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4b533ffdf964a5201a9427e3',
#     'name': 'Muddy Duck Restaurant',
#     'location': {'address': '2200 Dundas St. E',
#      'crossStreet': 'btw Regional Rd. 4 & Highway 407',
#      'lat': 43.62597233051833,
#      'lng': -79.56542718415807,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.62597233051833,
#        'lng': -79.56542718415807}],
#      'distance': 2171,
#      'postalCode': 'L4X 2V3',
#      'cc': 'CA',
#      'neighborhood': 'Islington - City Centre West',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2200 Dundas St. E (btw Regional Rd. 4 & Highway 407)',
#       'Mississauga ON L4X 2V3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '50b633dee4b0efc209002435',
#     'name': 'The Olive Restaurant',
#     'location': {'address': '100 The East Mall',
#      'crossStreet': 'North Queen',
#      'lat': 43.619846,
#      'lng': -79.54969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.619846,
#        'lng': -79.54969}],
#      'distance': 3443,
#      'postalCode': 'M8Z 5X2',
#      'cc': 'CA',
#      'neighborhood': 'Islington - City Centre West',
#      'city': 'Etobicoke',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 The East Mall (North Queen)',
#       'Etobicoke ON M8Z 5X2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4bdf6678e75c0f470617cb03',
#     'name': 'Silk Road Restaurant 丝绸之路',
#     'location': {'address': '1852 Dundas St E',
#      'crossStreet': 'at Wharton Way',
#      'lat': 43.61927817099883,
#      'lng': -79.57303110058828,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.61927817099883,
#        'lng': -79.57303110058828}],
#      'distance': 2718,
#      'postalCode': 'L4X 1L9',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1852 Dundas St E (at Wharton Way)',
#       'Mississauga ON L4X 1L9',
#       'Canada']},
#     'categories': [{'id': '52af3b913cf9994f4e043c06',
#       'name': 'Xinjiang Restaurant',
#       'pluralName': 'Xinjiang Restaurants',
#       'shortName': 'Xinjiang',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '534b2c4c498e3290a42bc2f1',
#     'name': 'Cross Eyed Bear Restaurant',
#     'location': {'address': '555 Burnhamthorpe',
#      'crossStreet': 'The West Mall',
#      'lat': 43.64472458866585,
#      'lng': -79.56800937652586,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64472458866585,
#        'lng': -79.56800937652586}],
#      'distance': 752,
#      'postalCode': 'M9C 2Y3',
#      'cc': 'CA',
#      'city': 'Etobicoke',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['555 Burnhamthorpe (The West Mall)',
#       'Etobicoke ON M9C 2Y3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '5dd098c5bf319f0008b5ba8d',
#     'name': 'Kahramana Restaurant',
#     'location': {'address': '3415 Dixie Road Unit 4A',
#      'lat': 43.617805,
#      'lng': -79.595215,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.617805,
#        'lng': -79.595215}],
#      'distance': 3209,
#      'postalCode': 'L4Y 4J6',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3415 Dixie Road Unit 4A',
#       'Mississauga ON L4Y 4J6',
#       'Canada']},
#     'categories': [{'id': '5bae9231bedf3950379f89e7',
#       'name': 'Iraqi Restaurant',
#       'pluralName': 'Iraqi Restaurants',
#       'shortName': 'Iraqi Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4e8f1efebe7b11a0c4fd3f19',
#     'name': 'VAHALLA RESTAURANT',
#     'location': {'address': '314 W Center Ave',
#      'lat': 43.64095401822603,
#      'lng': -79.56495082156397,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64095401822603,
#        'lng': -79.56495082156397}],
#      'distance': 1027,
#      'postalCode': '93291',
#      'cc': 'CA',
#      'city': 'Vahalla',
#      'state': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['314 W Center Ave', 'Vahalla CA 93291', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c6941735',
#       'name': 'Scandinavian Restaurant',
#       'pluralName': 'Scandinavian Restaurants',
#       'shortName': 'Scandinavian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4c3285c6a0ced13abf56156e',
#     'name': 'Best Friend Chinese Restaurant 老友記小廚',
#     'location': {'address': '888 Dundas St. E., Unit D1B',
#      'lat': 43.59775555918656,
#      'lng': -79.59422665777298,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.59775555918656,
#        'lng': -79.59422665777298}],
#      'distance': 5275,
#      'postalCode': 'L4Y 4G6',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['888 Dundas St. E., Unit D1B',
#       'Mississauga ON L4Y 4G6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4b80c40ef964a520e68a30e3',
#     'name': 'Perkins Restaurant & Bakery',
#     'location': {'address': '600 Dixon Rd',
#      'crossStreet': 'at Martin Grove Rd',
#      'lat': 43.691977481453655,
#      'lng': -79.57281053066248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.691977481453655,
#        'lng': -79.57281053066248}],
#      'distance': 5406,
#      'postalCode': 'M9W 1J1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['600 Dixon Rd (at Martin Grove Rd)',
#       'Toronto ON M9W 1J1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4b9e3781f964a5208fd236e3',
#     'name': 'Restaurant Savana',
#     'location': {'lat': 43.652165944622695,
#      'lng': -79.64177014720548,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652165944622695,
#        'lng': -79.64177014720548}],
#      'distance': 5289,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4bfefc3b68c7a593dc004044',
#     'name': 'Golden Wok Chinese Restaurant',
#     'location': {'address': '120 Eringate Dr. Unit #3',
#      'crossStreet': 'Renforth Dr',
#      'lat': 43.66049068196177,
#      'lng': -79.58231896162033,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66049068196177,
#        'lng': -79.58231896162033}],
#      'distance': 1934,
#      'postalCode': 'M9C 3Z8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['120 Eringate Dr. Unit #3 (Renforth Dr)',
#       'Toronto ON M9C 3Z8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4d865eff7e8ef04d71a733be',
#     'name': 'Croatia Restaurant',
#     'location': {'address': '1989 Dundas St E',
#      'lat': 43.622139684720345,
#      'lng': -79.57194157824344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.622139684720345,
#        'lng': -79.57194157824344}],
#      'distance': 2416,
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1989 Dundas St E', 'Mississauga ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d109941735',
#       'name': 'Eastern European Restaurant',
#       'pluralName': 'Eastern European Restaurants',
#       'shortName': 'Eastern European',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4bd8c3c43749952129f65985',
#     'name': 'The Bounty Restaurant',
#     'location': {'address': '2206 Dundas St. E.',
#      'lat': 43.626234432619576,
#      'lng': -79.56505386378636,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.626234432619576,
#        'lng': -79.56505386378636}],
#      'distance': 2158,
#      'postalCode': 'L4X 1L9',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2206 Dundas St. E.',
#       'Mississauga ON L4X 1L9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4bd1d1759854d13a1145fa4d',
#     'name': 'Sky Restaurant Cocktail Lounge',
#     'location': {'address': '2680 Skymark Avenue',
#      'lat': 43.659396271516535,
#      'lng': -79.5962905883789,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.659396271516535,
#        'lng': -79.5962905883789}],
#      'distance': 2342,
#      'postalCode': 'L4W 5L6',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2680 Skymark Avenue',
#       'Mississauga ON L4W 5L6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4d5ac0f523e0a093f9bb5249',
#     'name': 'Ontario Restaurant Hotel & Motel Assoc',
#     'location': {'address': '2600 Skymark Ave #8-201',
#      'lat': 43.657808199577225,
#      'lng': -79.59773796703776,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657808199577225,
#        'lng': -79.59773796703776}],
#      'distance': 2295,
#      'postalCode': 'L4W 5B2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2600 Skymark Ave #8-201',
#       'Toronto ON L4W 5B2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4c881a9d7223b1f7c1fb28a8',
#     'name': 'Mekong River Restaurant',
#     'location': {'address': '5468 Dundas St. W',
#      'lat': 43.632642961028864,
#      'lng': -79.54418447088408,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.632642961028864,
#        'lng': -79.54418447088408}],
#      'distance': 2922,
#      'postalCode': 'M6N',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5468 Dundas St. W', 'Toronto ON M6N', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '548815de498e3487cda854d3',
#     'name': 'Dragon Palace Chinese Restaurant',
#     'location': {'address': '1850 Dundas St E',
#      'lat': 43.61880362343542,
#      'lng': -79.57328796386717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.61880362343542,
#        'lng': -79.57328796386717}],
#      'distance': 2768,
#      'postalCode': 'L4X 1L9',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1850 Dundas St E',
#       'Mississauga ON L4X 1L9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4c8e68ccd2aea0934838ce69',
#     'name': 'Dynasty BBQ restaurant',
#     'location': {'address': '1550 South Gateway',
#      'lat': 43.63194255158574,
#      'lng': -79.61455213795152,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63194255158574,
#        'lng': -79.61455213795152}],
#      'distance': 3273,
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1550 South Gateway', 'Mississauga ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4de2bedb52b1d38d2976329f',
#     'name': 'Ezone Tap & Grill Restaurant',
#     'location': {'address': '95 The East Mall',
#      'lat': 43.62071807122642,
#      'lng': -79.54886864019383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.62071807122642,
#        'lng': -79.54886864019383}],
#      'distance': 3413,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['95 The East Mall', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '52191d4311d21c9af2df9a09',
#     'name': 'Lac Vien Vietnamese Restaurant - Mississauga',
#     'location': {'address': '1580 Dundas St E',
#      'crossStreet': 'at Matawa Ave',
#      'lat': 43.61350209873405,
#      'lng': -79.57860525201646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.61350209873405,
#        'lng': -79.57860525201646}],
#      'distance': 3342,
#      'postalCode': 'L4X 2Z2',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1580 Dundas St E (at Matawa Ave)',
#       'Mississauga ON L4X 2Z2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '137090881'},
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '58111def38faa4d340ba3782',
#     'name': 'Montreal Delicatessen & Family Restaurant',
#     'location': {'address': '2055 Dundas Street E',
#      'lat': 43.617964771585214,
#      'lng': -79.56191539764404,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.617964771585214,
#        'lng': -79.56191539764404}],
#      'distance': 3099,
#      'postalCode': 'L4X 2V9',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2055 Dundas Street E',
#       'Mississauga ON L4X 2V9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '357466379'},
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '5f4050ead8073f503a48f1db',
#     'name': 'Mama Rosa Restaurant & Bar',
#     'location': {'address': '5078 Dundas St W',
#      'lat': 43.645315,
#      'lng': -79.531938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645315,
#        'lng': -79.531938}],
#      'distance': 3651,
#      'postalCode': 'M9A 1B9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5078 Dundas St W', 'Toronto ON M9A 1B9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4c4b383c9c8d2d7f6d74ab6a',
#     'name': 'IKEA Restaurant',
#     'location': {'address': '1475 The Queensway',
#      'crossStreet': 'at Holly St',
#      'lat': 43.618156,
#      'lng': -79.53455,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.618156,
#        'lng': -79.53455}],
#      'distance': 4447,
#      'postalCode': 'M8Z 1T3',
#      'cc': 'CA',
#      'neighborhood': 'Islington - City Centre West',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1475 The Queensway (at Holly St)',
#       'Toronto ON M8Z 1T3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4bcb9b5a68f976b0717e6183',
#     'name': 'Anatolia Restaurant',
#     'location': {'address': '5112 Dundas St West',
#      'lat': 43.64459569284515,
#      'lng': -79.53280970144667,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64459569284515,
#        'lng': -79.53280970144667}],
#      'distance': 3577,
#      'postalCode': 'M9A 1C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5112 Dundas St West',
#       'Toronto ON M9A 1C2',
#       'Canada']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '46443284'},
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4b5a0ca9f964a5200aaa28e3',
#     'name': 'Plaka Restaurant',
#     'location': {'address': '2601 Matheson Blvd East',
#      'crossStreet': 'Orbitor',
#      'lat': 43.6594188605776,
#      'lng': -79.60164691866383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6594188605776,
#        'lng': -79.60164691866383}],
#      'distance': 2647,
#      'cc': 'CA',
#      'neighborhood': 'Etobicoke',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2601 Matheson Blvd East (Orbitor)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10e941735',
#       'name': 'Greek Restaurant',
#       'pluralName': 'Greek Restaurants',
#       'shortName': 'Greek',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4c1bb2e5b9f876b0b2ac7a46',
#     'name': 'Canadiana Restaurant & Banquet Hall',
#     'location': {'address': '5230 Dundas St W',
#      'crossStreet': 'at Six Point Plaza',
#      'lat': 43.639742,
#      'lng': -79.536993,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.639742,
#        'lng': -79.536993}],
#      'distance': 3266,
#      'postalCode': 'M9B 1A8',
#      'cc': 'CA',
#      'city': 'Etobicoke',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5230 Dundas St W (at Six Point Plaza)',
#       'Etobicoke ON M9B 1A8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4e7bb7a552b14ada7832b979',
#     'name': 'Canoe Restaurant',
#     'location': {'lat': 43.6326287870478,
#      'lng': -79.6151307465953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6326287870478,
#        'lng': -79.6151307465953}],
#      'distance': 3287,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '549eb21c498e58bd4f707bbc',
#     'name': 'Gohyang Sushi Restaurant',
#     'location': {'address': '5096 Dundas St West',
#      'crossStreet': 'Dundas & Bloor',
#      'lat': 43.645012243543974,
#      'lng': -79.53262941993918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645012243543974,
#        'lng': -79.53262941993918}],
#      'distance': 3594,
#      'postalCode': 'M9A 1C2',
#      'cc': 'CA',
#      'city': 'Etobicoke',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5096 Dundas St West (Dundas & Bloor)',
#       'Etobicoke ON M9A 1C2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4f7788d8e4b08e5a67c2e88d',
#     'name': 'King Kebab Turkish Restaurant',
#     'location': {'address': '5130 Dixie Rd, Unit 6',
#      'lat': 43.6368,
#      'lng': -79.623821,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6368,
#        'lng': -79.623821}],
#      'distance': 3829,
#      'postalCode': 'L4W 1C9',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5130 Dixie Rd, Unit 6',
#       'Mississauga ON L4W 1C9',
#       'Canada']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4e2742291f6eb1ae139df459',
#     'name': 'Naughty Nadz Bar and Restaurant',
#     'location': {'address': '1590 Dundas Street East',
#      'lat': 43.61406503903949,
#      'lng': -79.57865197882408,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.61406503903949,
#        'lng': -79.57865197882408}],
#      'distance': 3280,
#      'postalCode': 'L4X 2Z2',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1590 Dundas Street East',
#       'Mississauga ON L4X 2Z2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4c1e8799fcf8c9b67a6bad0b',
#     'name': 'Hometown Restaurant',
#     'location': {'address': '5096A Dundas Street West',
#      'lat': 43.644837158030654,
#      'lng': -79.53216281884893,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644837158030654,
#        'lng': -79.53216281884893}],
#      'distance': 3631,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5096A Dundas Street West', 'Toronto ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4d123955d1848cfa4e26ba71',
#     'name': 'Sunrise Caribbean Restaurant',
#     'location': {'lat': 43.641558,
#      'lng': -79.622696,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.641558,
#        'lng': -79.622696}],
#      'distance': 3671,
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Mississauga ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '50318506e4b0f8a001cadc57',
#     'name': 'Eat More Restaurant - Fine Pakistani Cuisini',
#     'location': {'address': '5130 Dixie Road, Unit 14',
#      'lat': 43.63650055182642,
#      'lng': -79.62408321872671,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63650055182642,
#        'lng': -79.62408321872671}],
#      'distance': 3856,
#      'postalCode': 'L4W 4K2',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5130 Dixie Road, Unit 14',
#       'Mississauga ON L4W 4K2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4d5b16739c8a236a2a1cdb14',
#     'name': "Song Cook's Authentic Korean Restaurant",
#     'location': {'address': '1310 Dundas Street E',
#      'crossStreet': 'at Dixie Rd.',
#      'lat': 43.6072496854037,
#      'lng': -79.58570737408566,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6072496854037,
#        'lng': -79.58570737408566}],
#      'distance': 4094,
#      'postalCode': 'L4Y 2C1',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1310 Dundas Street E (at Dixie Rd.)',
#       'Mississauga ON L4Y 2C1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4d7a565c79e6721e4acb588b',
#     'name': 'Gospel Cafe & Restaurant',
#     'location': {'address': '5120 Dixie Rd, Unit 9',
#      'lat': 43.63650983333334,
#      'lng': -79.623512,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63650983333334,
#        'lng': -79.623512}],
#      'distance': 3811,
#      'postalCode': 'L4W 4J7',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5120 Dixie Rd, Unit 9',
#       'Mississauga ON L4W 4J7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4b81ae16f964a52067b730e3',
#     'name': 'Montreal Deli',
#     'location': {'address': '2055 Dundas St. E',
#      'crossStreet': 'at Southcreek Rd.',
#      'lat': 43.62382599489847,
#      'lng': -79.56916479582966,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.62382599489847,
#        'lng': -79.56916479582966}],
#      'distance': 2285,
#      'postalCode': 'L4X 1M2',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2055 Dundas St. E (at Southcreek Rd.)',
#       'Mississauga ON L4X 1M2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '54a4b507498e87a65d9517c5',
#     'name': 'Twist Restaurant',
#     'location': {'lat': 43.67978748816157,
#      'lng': -79.61619932533664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67978748816157,
#        'lng': -79.61619932533664}],
#      'distance': 5115,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'shortName': 'Gastropub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '5692800e498e98773c62095c',
#     'name': 'JAM House Seafood Restaurant',
#     'location': {'address': '1425 Dundas St E',
#      'crossStreet': 'at Dixie Rd',
#      'lat': 43.610740783536,
#      'lng': -79.58441282511949,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.610740783536,
#        'lng': -79.58441282511949}],
#      'distance': 3694,
#      'postalCode': 'L4X 1L4',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1425 Dundas St E (at Dixie Rd)',
#       'Mississauga ON L4X 1L4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '50ee5fbfe4b09ea99de765a4',
#     'name': 'Alio Restaurant & Wine Bar',
#     'location': {'address': '108 Dundas St. W',
#      'lat': 43.64133716346786,
#      'lng': -79.52719474153162,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64133716346786,
#        'lng': -79.52719474153162}],
#      'distance': 4035,
#      'postalCode': 'M5G 1C3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['108 Dundas St. W', 'Toronto ON M5G 1C3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '59e90e220313201e3d2f3671',
#     'name': 'Pho Ngoc Yen Restaurant',
#     'location': {'address': '1090 Kamata Rd',
#      'lat': 43.6387,
#      'lng': -79.64352,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6387,
#        'lng': -79.64352}],
#      'distance': 5369,
#      'postalCode': 'L4W 2P3',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1090 Kamata Rd',
#       'Mississauga ON L4W 2P3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4bf0715d17880f47f2532937',
#     'name': "Leao D'ouro Restaurant",
#     'location': {'address': '920 Dundas Street East',
#      'crossStreet': 'Dundas & Tomken',
#      'lat': 43.599536,
#      'lng': -79.594372,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.599536,
#        'lng': -79.594372}],
#      'distance': 5087,
#      'postalCode': 'L4Y 2B8',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['920 Dundas Street East (Dundas & Tomken)',
#       'Mississauga ON L4Y 2B8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4b3e7beaf964a520d09d25e3',
#     'name': 'Lemongrass Thai Restaurant',
#     'location': {'address': '847 Albion Rd',
#      'crossStreet': 'E of Islington Ave',
#      'lat': 43.64432613778583,
#      'lng': -79.52301146546185,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64432613778583,
#        'lng': -79.52301146546185}],
#      'distance': 4366,
#      'postalCode': 'M9V 1A3',
#      'cc': 'CA',
#      'city': 'Etobicoke',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['847 Albion Rd (E of Islington Ave)',
#       'Etobicoke ON M9V 1A3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4d59b9798492a1433aca2a27',
#     'name': 'Montreal Delicatessen Family Restaurant',
#     'location': {'address': '2055 Dundas st E',
#      'lat': 43.62740078160996,
#      'lng': -79.62649375784117,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.62740078160996,
#        'lng': -79.62649375784117}],
#      'distance': 4357,
#      'postalCode': 'L4X',
#      'cc': 'CA',
#      'city': 'Oakvill',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2055 Dundas st E', 'Oakvill ON L4X', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '5e2889696577fa000807b875',
#     'name': "GYRO'S Place Greek Restaurant",
#     'location': {'address': '1350 Matheson Blvd E',
#      'lat': 43.64152273633685,
#      'lng': -79.63231801986694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64152273633685,
#        'lng': -79.63231801986694}],
#      'distance': 4445,
#      'postalCode': 'L4W 4M1',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1350 Matheson Blvd E',
#       'Mississauga ON L4W 4M1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10e941735',
#       'name': 'Greek Restaurant',
#       'pluralName': 'Greek Restaurants',
#       'shortName': 'Greek',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4e84fce77ee6763749952413',
#     'name': 'I Love Sushi',
#     'location': {'address': '4944 Dundas St. W.',
#      'crossStreet': 'at Cordova Ave.',
#      'lat': 43.64839291560182,
#      'lng': -79.52921473544211,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64839291560182,
#        'lng': -79.52921473544211}],
#      'distance': 3903,
#      'postalCode': 'M9A 1B7',
#      'cc': 'CA',
#      'city': 'Etobicoke',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4944 Dundas St. W. (at Cordova Ave.)',
#       'Etobicoke ON M9A 1B7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4d67cbda5b376dcb9a687067',
#     'name': 'Wing Sun Coffee and Chinese Restaurant',
#     'location': {'address': '925 rathburn road east',
#      'lat': 43.61569,
#      'lng': -79.61781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.61569,
#        'lng': -79.61781}],
#      'distance': 4505,
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['925 rathburn road east',
#       'Mississauga ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4cf137fd1c158cfa7b5ccfb5',
#     'name': "Berina's Specialty Restaurant & Grill",
#     'location': {'address': '889 Pantera Dr',
#      'crossStreet': 'Tomken & Pantera',
#      'lat': 43.628863,
#      'lng': -79.641384,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.628863,
#        'lng': -79.641384}],
#      'distance': 5422,
#      'postalCode': 'L4W 2R9',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['889 Pantera Dr (Tomken & Pantera)',
#       'Mississauga ON L4W 2R9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d109941735',
#       'name': 'Eastern European Restaurant',
#       'pluralName': 'Eastern European Restaurants',
#       'shortName': 'Eastern European',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4be9ebe561aca5932f2f8300',
#     'name': 'Xuan Mai Vietnamese Restaurant',
#     'location': {'address': '1133 Dundas St. E, Unit 6',
#      'lat': 43.60192433333333,
#      'lng': -79.58873633333333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.60192433333333,
#        'lng': -79.58873633333333}],
#      'distance': 4722,
#      'postalCode': 'L5R 2N2',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1133 Dundas St. E, Unit 6',
#       'Mississauga ON L5R 2N2',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '5943319049281440e2aa1b4a',
#     'name': 'Sikgaek Korean Restaurant',
#     'location': {'address': '800 Dundas Street East, #A1',
#      'crossStreet': 'Haines road',
#      'lat': 43.60003,
#      'lng': -79.59311,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.60003,
#        'lng': -79.59311}],
#      'distance': 5007,
#      'postalCode': 'L4Y 2B6',
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['800 Dundas Street East, #A1 (Haines road)',
#       'Mississauga ON L4Y 2B6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '4fbc3211e4b000527bcd1b1b',
#     'name': 'Quatrefoil Restaurant',
#     'location': {'lat': 43.687207,
#      'lng': -79.588332,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.687207,
#        'lng': -79.588332}],
#      'distance': 4945,
#      'cc': 'CA',
#      'city': 'Dundas',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Dundas ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False},
#    {'id': '528811f5498e77725c158fe9',
#     'name': 'Pho Mi Vietnamese Restaurant',
#     'location': {'address': '4557 Hurontario St. (at Eglinton Ave.)',
#      'lat': 43.616566,
#      'lng': -79.629112,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.616566,
#        'lng': -79.629112}],
#      'distance': 5147,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['4557 Hurontario St. (at Eglinton Ave.)', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626641736',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
MW_df = json_normalize(venues)
MW_df.head()
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                        name  \
# 0  4b533ffdf964a5201a9427e3       Muddy Duck Restaurant
# 1  50b633dee4b0efc209002435        The Olive Restaurant
# 2  4bdf6678e75c0f470617cb03   Silk Road Restaurant 丝绸之路
# 3  534b2c4c498e3290a42bc2f1  Cross Eyed Bear Restaurant
# 4  5dd098c5bf319f0008b5ba8d        Kahramana Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1626641736    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1626641736    False
# 2  [{'id': '52af3b913cf9994f4e043c06', 'name': 'X...  v-1626641736    False
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1626641736    False
# 4  [{'id': '5bae9231bedf3950379f89e7', 'name': 'I...  v-1626641736    False
#
#           location.address              location.crossStreet  location.lat  \
# 0        2200 Dundas St. E  btw Regional Rd. 4 & Highway 407     43.625972
# 1        100 The East Mall                       North Queen     43.619846
# 2         1852 Dundas St E                    at Wharton Way     43.619278
# 3        555 Burnhamthorpe                     The West Mall     43.644725
# 4  3415 Dixie Road Unit 4A                               NaN     43.617805
#
#    location.lng                            location.labeledLatLngs  \
# 0    -79.565427  [{'label': 'display', 'lat': 43.62597233051833...
# 1    -79.549690  [{'label': 'display', 'lat': 43.619846, 'lng':...
# 2    -79.573031  [{'label': 'display', 'lat': 43.61927817099883...
# 3    -79.568009  [{'label': 'display', 'lat': 43.64472458866585...
# 4    -79.595215  [{'label': 'display', 'lat': 43.617805, 'lng':...
#
#    location.distance location.postalCode location.cc  \
# 0               2171             L4X 2V3          CA
# 1               3443             M8Z 5X2          CA
# 2               2718             L4X 1L9          CA
# 3                752             M9C 2Y3          CA
# 4               3209             L4Y 4J6          CA
#
#           location.neighborhood location.city location.state location.country  \
# 0  Islington - City Centre West   Mississauga             ON           Canada
# 1  Islington - City Centre West     Etobicoke             ON           Canada
# 2                           NaN   Mississauga             ON           Canada
# 3                           NaN     Etobicoke             ON           Canada
# 4                           NaN   Mississauga             ON           Canada
#
#                            location.formattedAddress venuePage.id
# 0  [2200 Dundas St. E (btw Regional Rd. 4 & Highw...          NaN
# 1  [100 The East Mall (North Queen), Etobicoke ON...          NaN
# 2  [1852 Dundas St E (at Wharton Way), Mississaug...          NaN
# 3  [555 Burnhamthorpe (The West Mall), Etobicoke ...          NaN
# 4  [3415 Dixie Road Unit 4A, Mississauga ON L4Y 4...          NaN

# %%
# Filtering columns with venue name + associated with location
filtered_columns = ['name', 'categories'] + [col for col in MW_df.columns if col.startswith('location.')] + ['id']
MW_df_filtered = MW_df.loc[:, filtered_columns]

# Filtering Venue per category
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filtering the category 
MW_df_filtered['categories'] = MW_df_filtered.apply(get_category_type, axis=1)
print ('\n Restaurants per Category to offer our Business Model Analisys')
MW_df_filtered
# Out:
#  Restaurants per Category to offer our Business Model Analisys
#                                             name                   categories  \
# 0                          Muddy Duck Restaurant          American Restaurant
# 1                           The Olive Restaurant                   Restaurant
# 2                      Silk Road Restaurant 丝绸之路          Xinjiang Restaurant
# 3                     Cross Eyed Bear Restaurant                   Restaurant
# 4                           Kahramana Restaurant             Iraqi Restaurant
# 5                             VAHALLA RESTAURANT      Scandinavian Restaurant
# 6           Best Friend Chinese Restaurant 老友記小廚           Chinese Restaurant
# 7                    Perkins Restaurant & Bakery          American Restaurant
# 8                              Restaurant Savana          American Restaurant
# 9                  Golden Wok Chinese Restaurant           Chinese Restaurant
# 10                            Croatia Restaurant  Eastern European Restaurant
# 11                         The Bounty Restaurant               Breakfast Spot
# 12                Sky Restaurant Cocktail Lounge          American Restaurant
# 13        Ontario Restaurant Hotel & Motel Assoc                       Office
# 14                       Mekong River Restaurant        Vietnamese Restaurant
# 15              Dragon Palace Chinese Restaurant           Chinese Restaurant
# 16                        Dynasty BBQ restaurant           Chinese Restaurant
# 17                  Ezone Tap & Grill Restaurant                    BBQ Joint
# 18  Lac Vien Vietnamese Restaurant - Mississauga        Vietnamese Restaurant
# 19     Montreal Delicatessen & Family Restaurant                   Restaurant
# 20                    Mama Rosa Restaurant & Bar                          Pub
# 21                               IKEA Restaurant         Fast Food Restaurant
# 22                           Anatolia Restaurant           Turkish Restaurant
# 23                              Plaka Restaurant             Greek Restaurant
# 24           Canadiana Restaurant & Banquet Hall                   Restaurant
# 25                              Canoe Restaurant                   Restaurant
# 26                      Gohyang Sushi Restaurant          Japanese Restaurant
# 27                 King Kebab Turkish Restaurant           Turkish Restaurant
# 28               Naughty Nadz Bar and Restaurant                          Bar
# 29                           Hometown Restaurant                         None
# 30                  Sunrise Caribbean Restaurant                         None
# 31  Eat More Restaurant - Fine Pakistani Cuisini            Indian Restaurant
# 32       Song Cook's Authentic Korean Restaurant            Korean Restaurant
# 33                      Gospel Cafe & Restaurant         Caribbean Restaurant
# 34                                 Montreal Deli                Deli / Bodega
# 35                              Twist Restaurant                    Gastropub
# 36                  JAM House Seafood Restaurant           Dim Sum Restaurant
# 37                    Alio Restaurant & Wine Bar                   Restaurant
# 38                       Pho Ngoc Yen Restaurant        Vietnamese Restaurant
# 39                        Leao D'ouro Restaurant                   Restaurant
# 40                    Lemongrass Thai Restaurant              Thai Restaurant
# 41       Montreal Delicatessen Family Restaurant                         None
# 42                 GYRO'S Place Greek Restaurant             Greek Restaurant
# 43                                  I Love Sushi             Sushi Restaurant
# 44        Wing Sun Coffee and Chinese Restaurant           Chinese Restaurant
# 45         Berina's Specialty Restaurant & Grill  Eastern European Restaurant
# 46                Xuan Mai Vietnamese Restaurant                         None
# 47                     Sikgaek Korean Restaurant            Korean Restaurant
# 48                         Quatrefoil Restaurant                   Restaurant
# 49                  Pho Mi Vietnamese Restaurant        Vietnamese Restaurant
#
#                           location.address              location.crossStreet  \
# 0                        2200 Dundas St. E  btw Regional Rd. 4 & Highway 407
# 1                        100 The East Mall                       North Queen
# 2                         1852 Dundas St E                    at Wharton Way
# 3                        555 Burnhamthorpe                     The West Mall
# 4                  3415 Dixie Road Unit 4A                               NaN
# 5                         314 W Center Ave                               NaN
# 6              888 Dundas St. E., Unit D1B                               NaN
# 7                             600 Dixon Rd                at Martin Grove Rd
# 8                                      NaN                               NaN
# 9                 120 Eringate Dr. Unit #3                       Renforth Dr
# 10                        1989 Dundas St E                               NaN
# 11                      2206 Dundas St. E.                               NaN
# 12                     2680 Skymark Avenue                               NaN
# 13                 2600 Skymark Ave #8-201                               NaN
# 14                       5468 Dundas St. W                               NaN
# 15                        1850 Dundas St E                               NaN
# 16                      1550 South Gateway                               NaN
# 17                        95 The East Mall                               NaN
# 18                        1580 Dundas St E                     at Matawa Ave
# 19                    2055 Dundas Street E                               NaN
# 20                        5078 Dundas St W                               NaN
# 21                      1475 The Queensway                       at Holly St
# 22                     5112 Dundas St West                               NaN
# 23                 2601 Matheson Blvd East                           Orbitor
# 24                        5230 Dundas St W                at Six Point Plaza
# 25                                     NaN                               NaN
# 26                     5096 Dundas St West                    Dundas & Bloor
# 27                   5130 Dixie Rd, Unit 6                               NaN
# 28                 1590 Dundas Street East                               NaN
# 29                5096A Dundas Street West                               NaN
# 30                                     NaN                               NaN
# 31                5130 Dixie Road, Unit 14                               NaN
# 32                    1310 Dundas Street E                      at Dixie Rd.
# 33                   5120 Dixie Rd, Unit 9                               NaN
# 34                       2055 Dundas St. E                 at Southcreek Rd.
# 35                                     NaN                               NaN
# 36                        1425 Dundas St E                       at Dixie Rd
# 37                        108 Dundas St. W                               NaN
# 38                          1090 Kamata Rd                               NaN
# 39                  920 Dundas Street East                   Dundas & Tomken
# 40                           847 Albion Rd                E of Islington Ave
# 41                        2055 Dundas st E                               NaN
# 42                    1350 Matheson Blvd E                               NaN
# 43                      4944 Dundas St. W.                   at Cordova Ave.
# 44                  925 rathburn road east                               NaN
# 45                          889 Pantera Dr                  Tomken & Pantera
# 46               1133 Dundas St. E, Unit 6                               NaN
# 47             800 Dundas Street East, #A1                       Haines road
# 48                                     NaN                               NaN
# 49  4557 Hurontario St. (at Eglinton Ave.)                               NaN
#
#     location.lat  location.lng  \
# 0      43.625972    -79.565427
# 1      43.619846    -79.549690
# 2      43.619278    -79.573031
# 3      43.644725    -79.568009
# 4      43.617805    -79.595215
# 5      43.640954    -79.564951
# 6      43.597756    -79.594227
# 7      43.691977    -79.572811
# 8      43.652166    -79.641770
# 9      43.660491    -79.582319
# 10     43.622140    -79.571942
# 11     43.626234    -79.565054
# 12     43.659396    -79.596291
# 13     43.657808    -79.597738
# 14     43.632643    -79.544184
# 15     43.618804    -79.573288
# 16     43.631943    -79.614552
# 17     43.620718    -79.548869
# 18     43.613502    -79.578605
# 19     43.617965    -79.561915
# 20     43.645315    -79.531938
# 21     43.618156    -79.534550
# 22     43.644596    -79.532810
# 23     43.659419    -79.601647
# 24     43.639742    -79.536993
# 25     43.632629    -79.615131
# 26     43.645012    -79.532629
# 27     43.636800    -79.623821
# 28     43.614065    -79.578652
# 29     43.644837    -79.532163
# 30     43.641558    -79.622696
# 31     43.636501    -79.624083
# 32     43.607250    -79.585707
# 33     43.636510    -79.623512
# 34     43.623826    -79.569165
# 35     43.679787    -79.616199
# 36     43.610741    -79.584413
# 37     43.641337    -79.527195
# 38     43.638700    -79.643520
# 39     43.599536    -79.594372
# 40     43.644326    -79.523011
# 41     43.627401    -79.626494
# 42     43.641523    -79.632318
# 43     43.648393    -79.529215
# 44     43.615690    -79.617810
# 45     43.628863    -79.641384
# 46     43.601924    -79.588736
# 47     43.600030    -79.593110
# 48     43.687207    -79.588332
# 49     43.616566    -79.629112
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 43.62597233051833...               2171
# 1   [{'label': 'display', 'lat': 43.619846, 'lng':...               3443
# 2   [{'label': 'display', 'lat': 43.61927817099883...               2718
# 3   [{'label': 'display', 'lat': 43.64472458866585...                752
# 4   [{'label': 'display', 'lat': 43.617805, 'lng':...               3209
# 5   [{'label': 'display', 'lat': 43.64095401822603...               1027
# 6   [{'label': 'display', 'lat': 43.59775555918656...               5275
# 7   [{'label': 'display', 'lat': 43.69197748145365...               5406
# 8   [{'label': 'display', 'lat': 43.65216594462269...               5289
# 9   [{'label': 'display', 'lat': 43.66049068196177...               1934
# 10  [{'label': 'display', 'lat': 43.62213968472034...               2416
# 11  [{'label': 'display', 'lat': 43.62623443261957...               2158
# 12  [{'label': 'display', 'lat': 43.65939627151653...               2342
# 13  [{'label': 'display', 'lat': 43.65780819957722...               2295
# 14  [{'label': 'display', 'lat': 43.63264296102886...               2922
# 15  [{'label': 'display', 'lat': 43.61880362343542...               2768
# 16  [{'label': 'display', 'lat': 43.63194255158574...               3273
# 17  [{'label': 'display', 'lat': 43.62071807122642...               3413
# 18  [{'label': 'display', 'lat': 43.61350209873405...               3342
# 19  [{'label': 'display', 'lat': 43.61796477158521...               3099
# 20  [{'label': 'display', 'lat': 43.645315, 'lng':...               3651
# 21  [{'label': 'display', 'lat': 43.618156, 'lng':...               4447
# 22  [{'label': 'display', 'lat': 43.64459569284515...               3577
# 23  [{'label': 'display', 'lat': 43.6594188605776,...               2647
# 24  [{'label': 'display', 'lat': 43.639742, 'lng':...               3266
# 25  [{'label': 'display', 'lat': 43.6326287870478,...               3287
# 26  [{'label': 'display', 'lat': 43.64501224354397...               3594
# 27  [{'label': 'display', 'lat': 43.6368, 'lng': -...               3829
# 28  [{'label': 'display', 'lat': 43.61406503903949...               3280
# 29  [{'label': 'display', 'lat': 43.64483715803065...               3631
# 30  [{'label': 'display', 'lat': 43.641558, 'lng':...               3671
# 31  [{'label': 'display', 'lat': 43.63650055182642...               3856
# 32  [{'label': 'display', 'lat': 43.6072496854037,...               4094
# 33  [{'label': 'display', 'lat': 43.63650983333334...               3811
# 34  [{'label': 'display', 'lat': 43.62382599489847...               2285
# 35  [{'label': 'display', 'lat': 43.67978748816157...               5115
# 36  [{'label': 'display', 'lat': 43.610740783536, ...               3694
# 37  [{'label': 'display', 'lat': 43.64133716346786...               4035
# 38  [{'label': 'display', 'lat': 43.6387, 'lng': -...               5369
# 39  [{'label': 'display', 'lat': 43.599536, 'lng':...               5087
# 40  [{'label': 'display', 'lat': 43.64432613778583...               4366
# 41  [{'label': 'display', 'lat': 43.62740078160996...               4357
# 42  [{'label': 'display', 'lat': 43.64152273633685...               4445
# 43  [{'label': 'display', 'lat': 43.64839291560182...               3903
# 44  [{'label': 'display', 'lat': 43.61569, 'lng': ...               4505
# 45  [{'label': 'display', 'lat': 43.628863, 'lng':...               5422
# 46  [{'label': 'display', 'lat': 43.60192433333333...               4722
# 47  [{'label': 'display', 'lat': 43.60003, 'lng': ...               5007
# 48  [{'label': 'display', 'lat': 43.687207, 'lng':...               4945
# 49  [{'label': 'display', 'lat': 43.616566, 'lng':...               5147
#
#    location.postalCode location.cc         location.neighborhood  \
# 0              L4X 2V3          CA  Islington - City Centre West
# 1              M8Z 5X2          CA  Islington - City Centre West
# 2              L4X 1L9          CA                           NaN
# 3              M9C 2Y3          CA                           NaN
# 4              L4Y 4J6          CA                           NaN
# 5                93291          CA                           NaN
# 6              L4Y 4G6          CA                           NaN
# 7              M9W 1J1          CA                           NaN
# 8                  NaN          CA                           NaN
# 9              M9C 3Z8          CA                           NaN
# 10                 NaN          CA                           NaN
# 11             L4X 1L9          CA                           NaN
# 12             L4W 5L6          CA                           NaN
# 13             L4W 5B2          CA                           NaN
# 14                 M6N          CA                           NaN
# 15             L4X 1L9          CA                           NaN
# 16                 NaN          CA                           NaN
# 17                 NaN          CA                           NaN
# 18             L4X 2Z2          CA                           NaN
# 19             L4X 2V9          CA                           NaN
# 20             M9A 1B9          CA                           NaN
# 21             M8Z 1T3          CA  Islington - City Centre West
# 22             M9A 1C2          CA                           NaN
# 23                 NaN          CA                     Etobicoke
# 24             M9B 1A8          CA                           NaN
# 25                 NaN          CA                           NaN
# 26             M9A 1C2          CA                           NaN
# 27             L4W 1C9          CA                           NaN
# 28             L4X 2Z2          CA                           NaN
# 29                 NaN          CA                           NaN
# 30                 NaN          CA                           NaN
# 31             L4W 4K2          CA                           NaN
# 32             L4Y 2C1          CA                           NaN
# 33             L4W 4J7          CA                           NaN
# 34             L4X 1M2          CA                           NaN
# 35                 NaN          CA                           NaN
# 36             L4X 1L4          CA                           NaN
# 37             M5G 1C3          CA                           NaN
# 38             L4W 2P3          CA                           NaN
# 39             L4Y 2B8          CA                           NaN
# 40             M9V 1A3          CA                           NaN
# 41                 L4X          CA                           NaN
# 42             L4W 4M1          CA                           NaN
# 43             M9A 1B7          CA                           NaN
# 44                 NaN          CA                           NaN
# 45             L4W 2R9          CA                           NaN
# 46             L5R 2N2          CA                           NaN
# 47             L4Y 2B6          CA                           NaN
# 48                 NaN          CA                           NaN
# 49                 NaN          CA                           NaN
#
#    location.city location.state location.country  \
# 0    Mississauga             ON           Canada
# 1      Etobicoke             ON           Canada
# 2    Mississauga             ON           Canada
# 3      Etobicoke             ON           Canada
# 4    Mississauga             ON           Canada
# 5        Vahalla             CA           Canada
# 6    Mississauga             ON           Canada
# 7        Toronto             ON           Canada
# 8            NaN            NaN           Canada
# 9        Toronto             ON           Canada
# 10   Mississauga             ON           Canada
# 11   Mississauga             ON           Canada
# 12   Mississauga             ON           Canada
# 13       Toronto             ON           Canada
# 14       Toronto             ON           Canada
# 15   Mississauga             ON           Canada
# 16   Mississauga             ON           Canada
# 17       Toronto             ON           Canada
# 18   Mississauga             ON           Canada
# 19   Mississauga             ON           Canada
# 20       Toronto             ON           Canada
# 21       Toronto             ON           Canada
# 22       Toronto             ON           Canada
# 23       Toronto             ON           Canada
# 24     Etobicoke             ON           Canada
# 25           NaN            NaN           Canada
# 26     Etobicoke             ON           Canada
# 27   Mississauga             ON           Canada
# 28   Mississauga             ON           Canada
# 29       Toronto             ON           Canada
# 30   Mississauga             ON           Canada
# 31   Mississauga             ON           Canada
# 32   Mississauga             ON           Canada
# 33   Mississauga             ON           Canada
# 34   Mississauga             ON           Canada
# 35           NaN            NaN           Canada
# 36   Mississauga             ON           Canada
# 37       Toronto             ON           Canada
# 38   Mississauga             ON           Canada
# 39   Mississauga             ON           Canada
# 40     Etobicoke             ON           Canada
# 41       Oakvill             ON           Canada
# 42   Mississauga             ON           Canada
# 43     Etobicoke             ON           Canada
# 44   Mississauga             ON           Canada
# 45   Mississauga             ON           Canada
# 46   Mississauga             ON           Canada
# 47   Mississauga             ON           Canada
# 48        Dundas             ON           Canada
# 49           NaN            NaN           Canada
#
#                             location.formattedAddress  \
# 0   [2200 Dundas St. E (btw Regional Rd. 4 & Highw...
# 1   [100 The East Mall (North Queen), Etobicoke ON...
# 2   [1852 Dundas St E (at Wharton Way), Mississaug...
# 3   [555 Burnhamthorpe (The West Mall), Etobicoke ...
# 4   [3415 Dixie Road Unit 4A, Mississauga ON L4Y 4...
# 5        [314 W Center Ave, Vahalla CA 93291, Canada]
# 6   [888 Dundas St. E., Unit D1B, Mississauga ON L...
# 7   [600 Dixon Rd (at Martin Grove Rd), Toronto ON...
# 8                                            [Canada]
# 9   [120 Eringate Dr. Unit #3 (Renforth Dr), Toron...
# 10         [1989 Dundas St E, Mississauga ON, Canada]
# 11  [2206 Dundas St. E., Mississauga ON L4X 1L9, C...
# 12  [2680 Skymark Avenue, Mississauga ON L4W 5L6, ...
# 13  [2600 Skymark Ave #8-201, Toronto ON L4W 5B2, ...
# 14        [5468 Dundas St. W, Toronto ON M6N, Canada]
# 15  [1850 Dundas St E, Mississauga ON L4X 1L9, Can...
# 16       [1550 South Gateway, Mississauga ON, Canada]
# 17             [95 The East Mall, Toronto ON, Canada]
# 18  [1580 Dundas St E (at Matawa Ave), Mississauga...
# 19  [2055 Dundas Street E, Mississauga ON L4X 2V9,...
# 20     [5078 Dundas St W, Toronto ON M9A 1B9, Canada]
# 21  [1475 The Queensway (at Holly St), Toronto ON ...
# 22  [5112 Dundas St West, Toronto ON M9A 1C2, Canada]
# 23  [2601 Matheson Blvd East (Orbitor), Toronto ON...
# 24  [5230 Dundas St W (at Six Point Plaza), Etobic...
# 25                                           [Canada]
# 26  [5096 Dundas St West (Dundas & Bloor), Etobico...
# 27  [5130 Dixie Rd, Unit 6, Mississauga ON L4W 1C9...
# 28  [1590 Dundas Street East, Mississauga ON L4X 2...
# 29     [5096A Dundas Street West, Toronto ON, Canada]
# 30                           [Mississauga ON, Canada]
# 31  [5130 Dixie Road, Unit 14, Mississauga ON L4W ...
# 32  [1310 Dundas Street E (at Dixie Rd.), Mississa...
# 33  [5120 Dixie Rd, Unit 9, Mississauga ON L4W 4J7...
# 34  [2055 Dundas St. E (at Southcreek Rd.), Missis...
# 35                                           [Canada]
# 36  [1425 Dundas St E (at Dixie Rd), Mississauga O...
# 37     [108 Dundas St. W, Toronto ON M5G 1C3, Canada]
# 38   [1090 Kamata Rd, Mississauga ON L4W 2P3, Canada]
# 39  [920 Dundas Street East (Dundas & Tomken), Mis...
# 40  [847 Albion Rd (E of Islington Ave), Etobicoke...
# 41         [2055 Dundas st E, Oakvill ON L4X, Canada]
# 42  [1350 Matheson Blvd E, Mississauga ON L4W 4M1,...
# 43  [4944 Dundas St. W. (at Cordova Ave.), Etobico...
# 44   [925 rathburn road east, Mississauga ON, Canada]
# 45  [889 Pantera Dr (Tomken & Pantera), Mississaug...
# 46  [1133 Dundas St. E, Unit 6, Mississauga ON L5R...
# 47  [800 Dundas Street East, #A1 (Haines road), Mi...
# 48                                [Dundas ON, Canada]
# 49   [4557 Hurontario St. (at Eglinton Ave.), Canada]
#
#                           id
# 0   4b533ffdf964a5201a9427e3
# 1   50b633dee4b0efc209002435
# 2   4bdf6678e75c0f470617cb03
# 3   534b2c4c498e3290a42bc2f1
# 4   5dd098c5bf319f0008b5ba8d
# 5   4e8f1efebe7b11a0c4fd3f19
# 6   4c3285c6a0ced13abf56156e
# 7   4b80c40ef964a520e68a30e3
# 8   4b9e3781f964a5208fd236e3
# 9   4bfefc3b68c7a593dc004044
# 10  4d865eff7e8ef04d71a733be
# 11  4bd8c3c43749952129f65985
# 12  4bd1d1759854d13a1145fa4d
# 13  4d5ac0f523e0a093f9bb5249
# 14  4c881a9d7223b1f7c1fb28a8
# 15  548815de498e3487cda854d3
# 16  4c8e68ccd2aea0934838ce69
# 17  4de2bedb52b1d38d2976329f
# 18  52191d4311d21c9af2df9a09
# 19  58111def38faa4d340ba3782
# 20  5f4050ead8073f503a48f1db
# 21  4c4b383c9c8d2d7f6d74ab6a
# 22  4bcb9b5a68f976b0717e6183
# 23  4b5a0ca9f964a5200aaa28e3
# 24  4c1bb2e5b9f876b0b2ac7a46
# 25  4e7bb7a552b14ada7832b979
# 26  549eb21c498e58bd4f707bbc
# 27  4f7788d8e4b08e5a67c2e88d
# 28  4e2742291f6eb1ae139df459
# 29  4c1e8799fcf8c9b67a6bad0b
# 30  4d123955d1848cfa4e26ba71
# 31  50318506e4b0f8a001cadc57
# 32  4d5b16739c8a236a2a1cdb14
# 33  4d7a565c79e6721e4acb588b
# 34  4b81ae16f964a52067b730e3
# 35  54a4b507498e87a65d9517c5
# 36  5692800e498e98773c62095c
# 37  50ee5fbfe4b09ea99de765a4
# 38  59e90e220313201e3d2f3671
# 39  4bf0715d17880f47f2532937
# 40  4b3e7beaf964a520d09d25e3
# 41  4d59b9798492a1433aca2a27
# 42  5e2889696577fa000807b875
# 43  4e84fce77ee6763749952413
# 44  4d67cbda5b376dcb9a687067
# 45  4cf137fd1c158cfa7b5ccfb5
# 46  4be9ebe561aca5932f2f8300
# 47  5943319049281440e2aa1b4a
# 48  4fbc3211e4b000527bcd1b1b
# 49  528811f5498e77725c158fe9

# %%
# count number of restaurants
print('There are',len(MW_df_filtered[['name']].drop_duplicates()),'Restaurants, under 5 Km Range from Toronto that we can offer this services!')
# Out:
# There are 50 Restaurants, under 5 Km Range from Toronto that we can offer this services!

# %% [markdown]
# ### Foursquare Restaurants

# %%
# Neighbourhood list

neighbourhood_list = list(final_loc_stats['Neighbourhood'])
neighbourhood_list[10]
# Out:
# 'Bayview Village'

# %%
# From Forsquare

# 5Km Distance range
radius = 5000
search_query = 'Restaurant*'

# Global variable
i=0

# Oount restaurants
count_restaurant = []


for x in neighbourhood_list:
    
    i
    latitude = final_loc_stats.iloc[i]['Latitude']
    longitude = final_loc_stats.iloc[i]['Longitude']
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
    results = requests.get(url).json()
    i = i + 1
    
    # JSON to venues
    venues = results['response']['venues']

    # Creating Venues dataframe
    total_df = json_normalize(venues)
    total_df.head()
    
    count_restaurant.append(len(total_df[['name']].drop_duplicates()))
    print(len(total_df[['name']].drop_duplicates()))
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:27: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# 50
# 50
# 50
# 50
# 50
# 50
# 48
# 48
# 47
# 48
# 48
# 46
# 49
# 48
# 50
# 50
# 50
# 50
# 49
# 50
# 50
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 22
# 46
# 46
# 50
# 50
# 46

# %%
from pandas import DataFrame as df
count_restaurant_df = df(count_restaurant,columns=['Restaurant Count'])
count_restaurant_df
# Out:
#     Restaurant Count
# 0                 50
# 1                 50
# 2                 50
# 3                 50
# 4                 50
# 5                 50
# 6                 48
# 7                 48
# 8                 47
# 9                 48
# 10                48
# 11                46
# 12                49
# 13                48
# 14                50
# 15                50
# 16                50
# 17                50
# 18                49
# 19                50
# 20                50
# 21                49
# 22                49
# 23                49
# 24                49
# 25                49
# 26                49
# 27                49
# 28                49
# 29                22
# 30                46
# 31                46
# 32                50
# 33                50
# 34                46

# %% [markdown]
# ## Restaurants per Neighborhood

# %%
from pandas import DataFrame as df

final_loc_stat_2 = final_loc_stats

count_restaurant_df = df(count_restaurant,columns=['Restaurant Count']) 
final_loc_stat_2 = final_loc_stat_2.join(count_restaurant_df)
print ('\nRestaurants per Neighbourhood to offer our Business Model Analisys')
final_loc_stat_2
# Out:
# Restaurants per Neighbourhood to offer our Business Model Analisys
#           Neighbourhood  After-Tax Household Income  Total Population  \
# 0         Markland Wood                     64297.0           10554.0
# 1           New Toronto                     40859.0           11463.0
# 2           Long Branch                     47680.0           10084.0
# 3             Alderwood                     61402.0           12054.0
# 4         Humber Summit                     53272.0           12416.0
# 5        Bathurst Manor                     51076.0           15873.0
# 6       Willowdale West                     54226.0           16936.0
# 7      Victoria Village                     43743.0           17510.0
# 8       Flemingdon Park                     43511.0           21933.0
# 9     Hillcrest Village                     57682.0           16934.0
# 10      Bayview Village                     58028.0           21396.0
# 11           Henry Farm                     47659.0           15723.0
# 12     Thorncliffe Park                     38645.0           21108.0
# 13          The Beaches                     70957.0           21567.0
# 14      Little Portugal                     52519.0           15559.0
# 15         Roncesvalles                     46883.0           14974.0
# 16    Forest Hill North                     53978.0           12806.0
# 17   Humewood-Cedarvale                     49252.0           14365.0
# 18               Weston                     41356.0           17992.0
# 19         Mount Dennis                     43790.0           13593.0
# 20             Oakridge                     32079.0           13845.0
# 21           Cliffcrest                     60384.0           15935.0
# 22         Kennedy Park                     41776.0           17123.0
# 23              Ionview                     42971.0           13641.0
# 24          Dorset Park                     47630.0           25003.0
# 25      Agincourt North                     55893.0           29113.0
# 26             Milliken                     55464.0           26572.0
# 27                Rouge                     72784.0           46496.0
# 28              Malvern                     53425.0           43794.0
# 29       Highland Creek                     87321.0           12494.0
# 30          Morningside                     50069.0           17455.0
# 31            West Hill                     46803.0           27392.0
# 32               Woburn                     47908.0           53485.0
# 33  Scarborough Village                     40181.0           16724.0
# 34            Guildwood                     67678.0            9917.0
#
#    Postcode          Borough   Latitude  Longitude  Restaurant Count
# 0       M9C        Etobicoke  43.643515 -79.577201                50
# 1       M8V        Etobicoke  43.605647 -79.501321                50
# 2       M8W        Etobicoke  43.602414 -79.543484                50
# 3       M8W        Etobicoke  43.602414 -79.543484                50
# 4       M9L       North York  43.756303 -79.565963                50
# 5       M3H       North York  43.754328 -79.442259                50
# 6       M2R       North York  43.782736 -79.442259                48
# 7       M4A       North York  43.725882 -79.315572                48
# 8       M3C       North York  43.725900 -79.340923                47
# 9       M2H       North York  43.803762 -79.363452                48
# 10      M2K       North York  43.786947 -79.385975                48
# 11      M2J       North York  43.778517 -79.346556                46
# 12      M4H        East York  43.705369 -79.349372                49
# 13      M4E     East Toronto  43.676357 -79.293031                48
# 14      M6J     West Toronto  43.647927 -79.419750                50
# 15      M6R     West Toronto  43.648960 -79.456325                50
# 16      M5P  Central Toronto  43.696948 -79.411307                50
# 17      M6C             York  43.693781 -79.428191                50
# 18      M9N             York  43.706876 -79.518188                49
# 19      M6M             York  43.691116 -79.476013                50
# 20      M1L      Scarborough  43.711112 -79.284577                50
# 21      M1M      Scarborough  43.716316 -79.239476                49
# 22      M1K      Scarborough  43.727929 -79.262029                49
# 23      M1K      Scarborough  43.727929 -79.262029                49
# 24      M1P      Scarborough  43.757410 -79.273304                49
# 25      M1V      Scarborough  43.815252 -79.284577                49
# 26      M1V      Scarborough  43.815252 -79.284577                49
# 27      M1B      Scarborough  43.806686 -79.194353                49
# 28      M1B      Scarborough  43.806686 -79.194353                49
# 29      M1C      Scarborough  43.784535 -79.160497                22
# 30      M1E      Scarborough  43.763573 -79.188711                46
# 31      M1E      Scarborough  43.763573 -79.188711                46
# 32      M1G      Scarborough  43.770992 -79.216917                50
# 33      M1J      Scarborough  43.744734 -79.239476                50
# 34      M1E      Scarborough  43.763573 -79.188711                46

# %% [markdown]
# ### Data Analysis

# %%
# libraries - JSON to pandas dataframe
from pandas.io.json import json_normalize 
import json

# Matplotlib
import matplotlib.cm as cm
import matplotlib.colors as colors
    
# Folium
# !pip install folium
import folium

print("\n\n############################################## All Libraries Imported with Success ##############################################")
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (1.19.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.22.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2.8)
#
#
# ############################################## All Libraries Imported with Success ##############################################

# %%
map_Toronto = folium.Map(location=[43.6532, -79.3832], zoom_start=10)

# copy df to aviid folium changing df
toronto_loc_f1 = final_loc_stats.copy()

# Markers on map
for lat, lng, borough, df_inner in zip(toronto_loc_f1['Latitude'], toronto_loc_f1['Longitude'], toronto_loc_f1['Borough'], toronto_loc_f1['Neighbourhood']):
    label = '{}, {}'.format(toronto_loc_f1, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='#3186ca',
        fill_opacity=0.9,
        parse_html=False).add_to(map_Toronto)  
print ('Toronto Map')    
map_Toronto
# Out:
# Toronto Map
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d4fd862790704e86a083e362d7bfb4c2%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d4fd862790704e86a083e362d7bfb4c2%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d4fd862790704e86a083e362d7bfb4c2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d4fd862790704e86a083e362d7bfb4c2%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6532%2C%20-79.3832%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# import matplotlib

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ### Chart - Household Income (Net)

# %%
# define df
df_income = final_loc_stat_2[['Neighbourhood', 'After-Tax Household Income']].set_index('Neighbourhood')

# sort > to <
df_income.sort_values(by='After-Tax Household Income', ascending=False, inplace=True)

# ploting
mpl.style.use('ggplot')
df_income.plot(kind='bar', figsize=(15,5), color='g')
plt.title('Household Income (Net) by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Net Household Income')

plt.show()

# %%
# Absoluute values: Net Household Income vs Neighborhood
df_income
# Out:
#                      After-Tax Household Income
# Neighbourhood
# Highland Creek                          87321.0
# Rouge                                   72784.0
# The Beaches                             70957.0
# Guildwood                               67678.0
# Markland Wood                           64297.0
# Alderwood                               61402.0
# Cliffcrest                              60384.0
# Bayview Village                         58028.0
# Hillcrest Village                       57682.0
# Agincourt North                         55893.0
# Milliken                                55464.0
# Willowdale West                         54226.0
# Forest Hill North                       53978.0
# Malvern                                 53425.0
# Humber Summit                           53272.0
# Little Portugal                         52519.0
# Bathurst Manor                          51076.0
# Morningside                             50069.0
# Humewood-Cedarvale                      49252.0
# Woburn                                  47908.0
# Long Branch                             47680.0
# Henry Farm                              47659.0
# Dorset Park                             47630.0
# Roncesvalles                            46883.0
# West Hill                               46803.0
# Mount Dennis                            43790.0
# Victoria Village                        43743.0
# Flemingdon Park                         43511.0
# Ionview                                 42971.0
# Kennedy Park                            41776.0
# Weston                                  41356.0
# New Toronto                             40859.0
# Scarborough Village                     40181.0
# Thorncliffe Park                        38645.0
# Oakridge                                32079.0

# %% [markdown]
# ### Chart - Population

# %%
# define df
df_pop = final_loc_stat_2[['Neighbourhood', 'Total Population']].set_index('Neighbourhood')

# sort by > to < 
df_pop.sort_values(by='Total Population', ascending=False, inplace=True)

# ploting
mpl.style.use('ggplot')
df_pop.plot(kind='bar', figsize=(15,5), color='navy')
plt.title('Total Population by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Total Population')

plt.show()

# %%
# Absoluute values: Total Population vs Neighbourhood
df_pop
# Out:
#                      Total Population
# Neighbourhood
# Woburn                        53485.0
# Rouge                         46496.0
# Malvern                       43794.0
# Agincourt North               29113.0
# West Hill                     27392.0
# Milliken                      26572.0
# Dorset Park                   25003.0
# Flemingdon Park               21933.0
# The Beaches                   21567.0
# Bayview Village               21396.0
# Thorncliffe Park              21108.0
# Weston                        17992.0
# Victoria Village              17510.0
# Morningside                   17455.0
# Kennedy Park                  17123.0
# Willowdale West               16936.0
# Hillcrest Village             16934.0
# Scarborough Village           16724.0
# Cliffcrest                    15935.0
# Bathurst Manor                15873.0
# Henry Farm                    15723.0
# Little Portugal               15559.0
# Roncesvalles                  14974.0
# Humewood-Cedarvale            14365.0
# Oakridge                      13845.0
# Ionview                       13641.0
# Mount Dennis                  13593.0
# Forest Hill North             12806.0
# Highland Creek                12494.0
# Humber Summit                 12416.0
# Alderwood                     12054.0
# New Toronto                   11463.0
# Markland Wood                 10554.0
# Long Branch                   10084.0
# Guildwood                      9917.0

# %% [markdown]
# ### Chart - Number of Restaurants

# %%
# define df
df_po_ven = final_loc_stat_2[['Neighbourhood', 'Restaurant Count']].set_index('Neighbourhood')

# sort by descending order
df_po_ven.sort_values(by='Restaurant Count', ascending=False, inplace=True)

# plot
mpl.style.use('ggplot')
df_po_ven.plot(kind='bar', figsize=(15,5), color='r')
plt.title('Restaurants by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Restaurants 5km Range')

plt.show()

# %%
# absolute number of Restaurants per Neighbourhood
df_po_ven
# Out:
#                      Restaurant Count
# Neighbourhood
# Markland Wood                      50
# Little Portugal                    50
# Scarborough Village                50
# Woburn                             50
# Oakridge                           50
# Mount Dennis                       50
# New Toronto                        50
# Forest Hill North                  50
# Roncesvalles                       50
# Humewood-Cedarvale                 50
# Long Branch                        50
# Alderwood                          50
# Bathurst Manor                     50
# Humber Summit                      50
# Kennedy Park                       49
# Dorset Park                        49
# Thorncliffe Park                   49
# Malvern                            49
# Rouge                              49
# Milliken                           49
# Weston                             49
# Cliffcrest                         49
# Agincourt North                    49
# Ionview                            49
# Bayview Village                    48
# Willowdale West                    48
# Victoria Village                   48
# Hillcrest Village                  48
# The Beaches                        48
# Flemingdon Park                    47
# Henry Farm                         46
# Morningside                        46
# West Hill                          46
# Guildwood                          46
# Highland Creek                     22

# %% [markdown]
# ### Clustering

# %%
#K-means
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

final_loc_stat_2
# Out:
#           Neighbourhood  After-Tax Household Income  Total Population  \
# 0         Markland Wood                     64297.0           10554.0
# 1           New Toronto                     40859.0           11463.0
# 2           Long Branch                     47680.0           10084.0
# 3             Alderwood                     61402.0           12054.0
# 4         Humber Summit                     53272.0           12416.0
# 5        Bathurst Manor                     51076.0           15873.0
# 6       Willowdale West                     54226.0           16936.0
# 7      Victoria Village                     43743.0           17510.0
# 8       Flemingdon Park                     43511.0           21933.0
# 9     Hillcrest Village                     57682.0           16934.0
# 10      Bayview Village                     58028.0           21396.0
# 11           Henry Farm                     47659.0           15723.0
# 12     Thorncliffe Park                     38645.0           21108.0
# 13          The Beaches                     70957.0           21567.0
# 14      Little Portugal                     52519.0           15559.0
# 15         Roncesvalles                     46883.0           14974.0
# 16    Forest Hill North                     53978.0           12806.0
# 17   Humewood-Cedarvale                     49252.0           14365.0
# 18               Weston                     41356.0           17992.0
# 19         Mount Dennis                     43790.0           13593.0
# 20             Oakridge                     32079.0           13845.0
# 21           Cliffcrest                     60384.0           15935.0
# 22         Kennedy Park                     41776.0           17123.0
# 23              Ionview                     42971.0           13641.0
# 24          Dorset Park                     47630.0           25003.0
# 25      Agincourt North                     55893.0           29113.0
# 26             Milliken                     55464.0           26572.0
# 27                Rouge                     72784.0           46496.0
# 28              Malvern                     53425.0           43794.0
# 29       Highland Creek                     87321.0           12494.0
# 30          Morningside                     50069.0           17455.0
# 31            West Hill                     46803.0           27392.0
# 32               Woburn                     47908.0           53485.0
# 33  Scarborough Village                     40181.0           16724.0
# 34            Guildwood                     67678.0            9917.0
#
#    Postcode          Borough   Latitude  Longitude  Restaurant Count
# 0       M9C        Etobicoke  43.643515 -79.577201                50
# 1       M8V        Etobicoke  43.605647 -79.501321                50
# 2       M8W        Etobicoke  43.602414 -79.543484                50
# 3       M8W        Etobicoke  43.602414 -79.543484                50
# 4       M9L       North York  43.756303 -79.565963                50
# 5       M3H       North York  43.754328 -79.442259                50
# 6       M2R       North York  43.782736 -79.442259                48
# 7       M4A       North York  43.725882 -79.315572                48
# 8       M3C       North York  43.725900 -79.340923                47
# 9       M2H       North York  43.803762 -79.363452                48
# 10      M2K       North York  43.786947 -79.385975                48
# 11      M2J       North York  43.778517 -79.346556                46
# 12      M4H        East York  43.705369 -79.349372                49
# 13      M4E     East Toronto  43.676357 -79.293031                48
# 14      M6J     West Toronto  43.647927 -79.419750                50
# 15      M6R     West Toronto  43.648960 -79.456325                50
# 16      M5P  Central Toronto  43.696948 -79.411307                50
# 17      M6C             York  43.693781 -79.428191                50
# 18      M9N             York  43.706876 -79.518188                49
# 19      M6M             York  43.691116 -79.476013                50
# 20      M1L      Scarborough  43.711112 -79.284577                50
# 21      M1M      Scarborough  43.716316 -79.239476                49
# 22      M1K      Scarborough  43.727929 -79.262029                49
# 23      M1K      Scarborough  43.727929 -79.262029                49
# 24      M1P      Scarborough  43.757410 -79.273304                49
# 25      M1V      Scarborough  43.815252 -79.284577                49
# 26      M1V      Scarborough  43.815252 -79.284577                49
# 27      M1B      Scarborough  43.806686 -79.194353                49
# 28      M1B      Scarborough  43.806686 -79.194353                49
# 29      M1C      Scarborough  43.784535 -79.160497                22
# 30      M1E      Scarborough  43.763573 -79.188711                46
# 31      M1E      Scarborough  43.763573 -79.188711                46
# 32      M1G      Scarborough  43.770992 -79.216917                50
# 33      M1J      Scarborough  43.744734 -79.239476                50
# 34      M1E      Scarborough  43.763573 -79.188711                46

# %%
k=5
final_loc_stat_3 = final_loc_stat_2
cluster = final_loc_stat_3.drop(['Postcode', 'Borough', 'Neighbourhood','After-Tax Household Income','Total Population','Restaurant Count'], axis = 1)
cluster.rename(columns={0:'Household Income', 1:'Population Size', 2:'Latitude', 3: 'Longtitude', 4:'Restaurant Count'}, inplace=True)
cluster.head(10)
# Out:
#     Latitude  Longitude
# 0  43.643515 -79.577201
# 1  43.605647 -79.501321
# 2  43.602414 -79.543484
# 3  43.602414 -79.543484
# 4  43.756303 -79.565963
# 5  43.754328 -79.442259
# 6  43.782736 -79.442259
# 7  43.725882 -79.315572
# 8  43.725900 -79.340923
# 9  43.803762 -79.363452

# %%
kmeans = KMeans(n_clusters = k,random_state=0).fit(cluster)
kmeans.labels_

Toronto_data = final_loc_stat_3
Toronto_data.insert(0, 'Cluster Labels', kmeans.labels_)
Toronto_data
# Out:
#     Cluster Labels        Neighbourhood  After-Tax Household Income  \
# 0                3        Markland Wood                     64297.0
# 1                3          New Toronto                     40859.0
# 2                3          Long Branch                     47680.0
# 3                3            Alderwood                     61402.0
# 4                3        Humber Summit                     53272.0
# 5                0       Bathurst Manor                     51076.0
# 6                0      Willowdale West                     54226.0
# 7                2     Victoria Village                     43743.0
# 8                2      Flemingdon Park                     43511.0
# 9                4    Hillcrest Village                     57682.0
# 10               4      Bayview Village                     58028.0
# 11               4           Henry Farm                     47659.0
# 12               2     Thorncliffe Park                     38645.0
# 13               2          The Beaches                     70957.0
# 14               0      Little Portugal                     52519.0
# 15               0         Roncesvalles                     46883.0
# 16               0    Forest Hill North                     53978.0
# 17               0   Humewood-Cedarvale                     49252.0
# 18               3               Weston                     41356.0
# 19               0         Mount Dennis                     43790.0
# 20               2             Oakridge                     32079.0
# 21               2           Cliffcrest                     60384.0
# 22               2         Kennedy Park                     41776.0
# 23               2              Ionview                     42971.0
# 24               2          Dorset Park                     47630.0
# 25               4      Agincourt North                     55893.0
# 26               4             Milliken                     55464.0
# 27               1                Rouge                     72784.0
# 28               1              Malvern                     53425.0
# 29               1       Highland Creek                     87321.0
# 30               1          Morningside                     50069.0
# 31               1            West Hill                     46803.0
# 32               1               Woburn                     47908.0
# 33               1  Scarborough Village                     40181.0
# 34               1            Guildwood                     67678.0
#
#     Total Population Postcode          Borough   Latitude  Longitude  \
# 0            10554.0      M9C        Etobicoke  43.643515 -79.577201
# 1            11463.0      M8V        Etobicoke  43.605647 -79.501321
# 2            10084.0      M8W        Etobicoke  43.602414 -79.543484
# 3            12054.0      M8W        Etobicoke  43.602414 -79.543484
# 4            12416.0      M9L       North York  43.756303 -79.565963
# 5            15873.0      M3H       North York  43.754328 -79.442259
# 6            16936.0      M2R       North York  43.782736 -79.442259
# 7            17510.0      M4A       North York  43.725882 -79.315572
# 8            21933.0      M3C       North York  43.725900 -79.340923
# 9            16934.0      M2H       North York  43.803762 -79.363452
# 10           21396.0      M2K       North York  43.786947 -79.385975
# 11           15723.0      M2J       North York  43.778517 -79.346556
# 12           21108.0      M4H        East York  43.705369 -79.349372
# 13           21567.0      M4E     East Toronto  43.676357 -79.293031
# 14           15559.0      M6J     West Toronto  43.647927 -79.419750
# 15           14974.0      M6R     West Toronto  43.648960 -79.456325
# 16           12806.0      M5P  Central Toronto  43.696948 -79.411307
# 17           14365.0      M6C             York  43.693781 -79.428191
# 18           17992.0      M9N             York  43.706876 -79.518188
# 19           13593.0      M6M             York  43.691116 -79.476013
# 20           13845.0      M1L      Scarborough  43.711112 -79.284577
# 21           15935.0      M1M      Scarborough  43.716316 -79.239476
# 22           17123.0      M1K      Scarborough  43.727929 -79.262029
# 23           13641.0      M1K      Scarborough  43.727929 -79.262029
# 24           25003.0      M1P      Scarborough  43.757410 -79.273304
# 25           29113.0      M1V      Scarborough  43.815252 -79.284577
# 26           26572.0      M1V      Scarborough  43.815252 -79.284577
# 27           46496.0      M1B      Scarborough  43.806686 -79.194353
# 28           43794.0      M1B      Scarborough  43.806686 -79.194353
# 29           12494.0      M1C      Scarborough  43.784535 -79.160497
# 30           17455.0      M1E      Scarborough  43.763573 -79.188711
# 31           27392.0      M1E      Scarborough  43.763573 -79.188711
# 32           53485.0      M1G      Scarborough  43.770992 -79.216917
# 33           16724.0      M1J      Scarborough  43.744734 -79.239476
# 34            9917.0      M1E      Scarborough  43.763573 -79.188711
#
#     Restaurant Count
# 0                 50
# 1                 50
# 2                 50
# 3                 50
# 4                 50
# 5                 50
# 6                 48
# 7                 48
# 8                 47
# 9                 48
# 10                48
# 11                46
# 12                49
# 13                48
# 14                50
# 15                50
# 16                50
# 17                50
# 18                49
# 19                50
# 20                50
# 21                49
# 22                49
# 23                49
# 24                49
# 25                49
# 26                49
# 27                49
# 28                49
# 29                22
# 30                46
# 31                46
# 32                50
# 33                50
# 34                46

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# Colors for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Map Markers
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_data['Latitude'], Toronto_data['Longitude'], Toronto_data['Neighbourhood'], Toronto_data['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.9).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a5e82bc764a24ba5b6745f8b60956e92%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a5e82bc764a24ba5b6745f8b60956e92%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a5e82bc764a24ba5b6745f8b60956e92%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a5e82bc764a24ba5b6745f8b60956e92%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.7635726%2C%20-79.1887115%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Best Value for K

# %%
final_loc_stat_4 = final_loc_stat_2
cluster_2 = final_loc_stat_3.drop(['Postcode', 'Borough', 'Neighbourhood','After-Tax Household Income','Total Population','Restaurant Count'], axis = 1)
cluster_2.rename(columns={0:'Household Income', 1:'Population Size', 2:'Latitude', 3: 'Longtitude', 4:'Restaurant Count'}, inplace=True)

from sklearn.cluster import KMeans
# !conda install -c districtdatalabs yellowbrick

from yellowbrick.cluster import KElbowVisualizer


# Clustering model and visualiser
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,10))

visualizer.fit(cluster_2)        
visualizer.show()
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Clusters Analysis
# ### Cluster Zero

# %%
Tonronto_data_C0 = Toronto_data.drop(['Postcode', 'Borough'], axis = 1)
Tonronto_data_C0 = Tonronto_data_C0[Tonronto_data_C0["Cluster Labels"].isin([0])]
Tonronto_data_C0_mean = Tonronto_data_C0.mean()
print ('\n Cluster Zero Analysis')
Tonronto_data_C0_mean
# Out:
#  Cluster Zero Analysis
# Cluster Labels                    0.000000
# After-Tax Household Income    50246.285714
# Total Population              14872.285714
# Latitude                         43.702257
# Longitude                       -79.439444
# Restaurant Count                 49.714286
# dtype: float64

# %%
stats_neighbourhood = pd.DataFrame (columns = ['Cluster Labels','After-Tax Household Income','Total Population', 'Latitude', 'Longitude', 'Restaurant Count'])

Tonronto_data_C = Toronto_data.drop(['Postcode', 'Borough'], axis = 1)
Tonronto_data_C0 = Tonronto_data_C[Tonronto_data_C["Cluster Labels"].isin([1])]
Toronto_data_C0_mean = Tonronto_data_C0.mean().to_frame().transpose()

stats_neighbourhood = stats_neighbourhood.append(Toronto_data_C0_mean, ignore_index = True)
print ('\n Cluster Zero Analysis')
stats_neighbourhood
# Out:
#  Cluster Zero Analysis
#    Cluster Labels  After-Tax Household Income  Total Population   Latitude  \
# 0             1.0                   58271.125         28469.625  43.775544
#
#    Longitude  Restaurant Count
# 0 -79.196466             44.75

# %% [markdown]
# ### All Clusters

# %%
i = 0
stats_neighbourhood = pd.DataFrame (columns = ['Cluster Labels','After-Tax Household Income','Total Population', 'Latitude', 'Longitude', 'Restaurant Count'])

for x in range (0, 5):

    Tonronto_data_C = Toronto_data.drop(['Postcode','Borough'], axis = 1)
    Tonronto_data_C0 = Tonronto_data_C[Tonronto_data_C["Cluster Labels"].isin([i])]
    Toronto_data_C0_mean = Tonronto_data_C0.mean().to_frame().transpose()

    stats_neighbourhood = stats_neighbourhood.append(Toronto_data_C0_mean, ignore_index = True)
    i = i + 1

print ('\n All Clusters Analysis')
stats_neighbourhood
# Out:
#  All Clusters Analysis
#    Cluster Labels  After-Tax Household Income  Total Population   Latitude  \
# 0             0.0                50246.285714      14872.285714  43.702257
# 1             1.0                58271.125000      28469.625000  43.775544
# 2             2.0                46855.111111      18629.444444  43.719356
# 3             3.0                51477.666667      12427.166667  43.652861
# 4             4.0                54945.200000      21947.600000  43.799946
#
#    Longitude  Restaurant Count
# 0 -79.439444         49.714286
# 1 -79.196466         44.750000
# 2 -79.291146         48.666667
# 3 -79.541607         49.833333
# 4 -79.333027         48.000000

# %%
from sklearn import preprocessing

# non-variable cols out 
stats_neighbourhood_norm = stats_neighbourhood.drop(['Cluster Labels','Latitude','Longitude', ], axis = 1)

x = stats_neighbourhood_norm.values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_normalised = pd.DataFrame(x_scaled)
df_normalised
# Out:
#           0         1         2
# 0  0.297054  0.152415  0.976581
# 1  1.000000  1.000000  0.000000
# 2  0.000000  0.386616  0.770492
# 3  0.404919  0.000000  1.000000
# 4  0.708661  0.593452  0.639344

# %% [markdown]
# ### Chart - Clustering

# %%
df_normalised_final = df_normalised.mean(axis=1).to_frame()
df_normalised_final .rename(columns={0:'Final Score'}, inplace=True)
df_normalised_final.sort_values(by='Final Score', ascending=False, inplace=True)

# plot graph
mpl.style.use('ggplot')
df_normalised_final.plot(kind='bar', figsize=(8,10), color='purple')
plt.title('Final Score')
plt.xlabel('Cluster')
plt.ylabel('Final Score')

plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
# Absolute values for the Score
df_normalised_final
# Out:
#    Final Score
# 1     0.666667
# 4     0.647153
# 0     0.475350
# 3     0.468306
# 2     0.385703

# %% [markdown]
# ### Final Analysis
# Cluster 4 is the best region for us to help the restaurants to implement the new delivery services, followed by cluster 1.
#
# Both clusters have a final score greater than 0.5 and therefore we consider them the most ideal for our work.
#
# ### Conclusion
# Joint activities with dissemination on social networks, combined with the data reported here, and the resilience of small business owners will be key to the success of this model created. The model created assumes that only the restaurants within this 5 km radius will serve customers residing in the neighborhood.
#
# Although this is potentially true, there are still other external factors that can influence it, such as delivery services for franchise networks that can operate within the same radius as the small business owner, so we always suggest that this analysis takes into account what should be done a marketing effort to support small local businesses.
#
# We do not believe that even after the lockdown falls, the model will become obsolete once the lockdown ends, as people will certainly see the social value of helping small businesses and creating jobs in their regions. Even if people go back to work in offices, we believe that small restaurants can offer this service at a cost differential for the consumer, who is already used to the same service done before.
#
# Population size and average family income alone produce limited results, but demand can also be driven by external data such as the popularity of available restaurants, the average age of the population in the regions, origin, quality of products, delivery to the time, fees, etc.
#
# In this way, we believe that we have an excellent tool to present to small business owners who want to expand their delivery services, especially restaurants and snack bars, and in this way, we will be helping them to have an alternative service, keeping their customers satisfied.
